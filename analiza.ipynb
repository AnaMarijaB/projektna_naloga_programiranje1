# %% [markdown]
# # Uvod v pandas
#  Tu dobtri lahko uporabljam _Markdown_

# %%
import pandas as pd

# %%
knjige = pd.read_csv('obdelani-podatki/knjige.csv')

# %%
knjige
# Out:
#                                                 naslov                avtor  \
# 0                                     The Hunger Games      Suzanne Collins
# 1            Harry Potter and the Order of the Phoenix         J.K. Rowling
# 2                                To Kill a Mockingbird           Harper Lee
# 3                                  Pride and Prejudice          Jane Austen
# 4                                             Twilight      Stephenie Meyer
# ..                                                 ...                  ...
# 595                                      The Goldfinch          Donna Tartt
# 596                             All the King&#39;s Men   Robert Penn Warren
# 597                                      Julius Caesar  William Shakespeare
# 598                                      Lover Eternal            J.R. Ward
# 599  Finding Hope in the Darkness of Grief: Spiritu...    Diamante Lavendar
#
#      ocena  vse_ocene  kon_ocena  vsi_glasovi
# ...

# %%
knjige[knjige.ocena >= 4.5]
# Out:
#                                                 naslov                  avtor  \
# 1            Harry Potter and the Order of the Phoenix           J.K. Rowling
# 8    J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...         J.R.R. Tolkien
# 71                Harry Potter and the Deathly Hallows           J.K. Rowling
# 93            Harry Potter and the Prisoner of Azkaban           J.K. Rowling
# 102                Harry Potter and the Goblet of Fire           J.K. Rowling
# 105             Harry Potter and the Half-Blood Prince           J.K. Rowling
# 110                               The Name of the Wind       Patrick Rothfuss
# 142                                  The Last Olympian           Rick Riordan
# 172                                 Clockwork Princess        Cassandra Clare
# 194                                  A Storm of Swords     George R.R. Martin
# 256                     The Complete Calvin and Hobbes         Bill Watterson
# ...

# %%
knjige.max()
# Out:
# naslov         زندگی مه آلود پریا
# avtor            سید مرتضی مصطفوی
# ocena                        4.82
# vse_ocene                  99,131
# kon_ocena                 980.557
# vsi_glasovi                 30496
# dtype: object

# %%
knjige.sort_values('vsi_glasovi')
# Out:
#                                                 naslov              avtor  \
# 599  Finding Hope in the Darkness of Grief: Spiritu...  Diamante Lavendar
# 562                                     Being and Time   Martin Heidegger
# 594                                      We Were Liars        E. Lockhart
# 582                                            Slammed     Colleen Hoover
# 595                                      The Goldfinch        Donna Tartt
# ..                                                 ...                ...
# 4                                             Twilight    Stephenie Meyer
# 3                                  Pride and Prejudice        Jane Austen
# 2                                To Kill a Mockingbird         Harper Lee
# 1            Harry Potter and the Order of the Phoenix       J.K. Rowling
# 0                                     The Hunger Games    Suzanne Collins
#
#      ocena  vse_ocene  kon_ocena  vsi_glasovi
# ...

# %%
knjige.groupby('vsi_glasovi').size()
# Out:
# vsi_glasovi
# 157      1
# 159      1
# 161      1
# 167      1
# 168      1
#         ..
# 14868    1
# 20421    1
# 23308    1
# 26908    1
# 30496    1
# Length: 472, dtype: int64

# %%
knjige.groupby('avtor').size()
# Out:
# avtor
# A.A. Milne               1
# Abraham   Verghese       1
# Agatha Christie          2
# Alan Moore               2
# Alan Paton               1
#                         ..
# Wilson Rawls             1
# Yann Martel              1
# Zora Neale Hurston       1
# أحمد جمال الدين رمضان    2
# سید مرتضی مصطفوی         1
# Length: 386, dtype: int64

# %%
knjige.groupby('ocena').mean()
# Out:
#        vsi_glasovi
# ocena
# 3.41        1597.0
# 3.43        1090.0
# 3.45         459.0
# 3.48         318.0
# 3.50         983.0
# ...            ...
# 4.60       12091.0
# 4.62        2109.0
# 4.63         357.0
# 4.73         323.0
# 4.82         632.0
#
# [107 rows x 1 columns]

# %% [markdown]
# neki.plot(x='kaj nej nariše', y='neki')
